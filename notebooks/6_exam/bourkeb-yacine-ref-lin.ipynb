# %% [markdown]
# # Mini-Projet
#
# Deux étapes principales :
# - Une analyse et prédiction des données de test à partir d'un modèle de régression.
# - Une classification des données d'apprentissage en plusieurs groupes, suivie d'une modélisation spécifique pour chaque groupe.
#
# Les données d'apprentissage sont stockées dans `donapp.csv` et les données de test dans `dontest.csv`.

# %% [markdown]
# ## Import des données

# %%
import pandas as pd
import os

# Ce programme cherche d'abord les fichiers dans le répertoire "data". Si les fichiers ne sont pas trouvés, il les cherche dans le répertoire courant.

# Définir le chemin des fichiers
data_path = 'data'
file_donapp = 'donapp.csv'
file_dontest = 'dontest.csv'

# Fonction pour charger les fichiers
def load_data(file_name):
    file_path = os.path.join(data_path, file_name)
    if os.path.exists(file_path):
        return pd.read_csv(file_path)
    else:
        return pd.read_csv(file_name)

# Charger les jeux de données
donapp = load_data(file_donapp)
dontest = load_data(file_dontest)

# Afficher les premières lignes pour vérification
print(donapp.head())
print(dontest.head())
# Out:
#    Pitch_angle  Pitch_angle_std  Hub_temperature  Hub_temperature_std  \
# 0    92.410004              0.0             8.24                 0.28
# 1    92.410004              0.0             6.83                 0.49
# 2    92.410004              0.0             2.00                 0.00
# 3    92.410004              0.0             3.96                 0.44
# 4    92.410004              0.0             4.00                 0.00
#
#    Generator_converter_speed  Generator_converter_speed_std  Generator_speed  \
# 0                       3.92                           0.01             0.17
# 1                       3.93                           0.38             0.17
# 2                       4.26                           0.02             0.00
# 3                       4.09                           0.01             0.06
# 4                       4.46                           0.02             0.43
#
#    Generator_speed_std  Generator_bearing_1_temperature  \
# 0                 0.80                             7.70
# 1                 1.89                             7.70
# 2                 0.05                            -1.69
# 3                 0.34                            -0.23
# 4                 0.36                             0.75
#
#    Generator_bearing_1_temperature_std  ...  Grid_frequency  \
# 0                                 0.01  ...       49.980000
# 1                                 0.00  ...        0.000000
# 2                                 0.10  ...       50.000000
# 3                                 0.05  ...       49.959999
# 4                                 0.03  ...       49.990002
#
#    Grid_frequency_std  Rotor_speed  Rotor_speed_std  \
# 0                0.01          0.0              0.0
# 1               22.26          0.0              0.0
# 2                0.01          0.0              0.0
# 3                0.01          0.0              0.0
# 4                0.01          0.0              0.0
#
#    Rotor_bearing_temperature  Rotor_bearing_temperature_std  Nacelle_angle_c  \
# 0                       2.38                           0.06       302.899990
# 1                       2.32                           0.03       302.899990
# 2                      -2.10                           0.07       301.810000
# 3                      -2.08                           0.04        79.000000
# 4                      -2.02                           0.03        69.120003
#
#    AbsWindSin  AbsWindCos      Y
# 0   -0.853187    0.521605 -2.727
# 1   -0.836286    0.548293  0.100
# 2    0.995193    0.097930 -4.993
# 3    0.973698    0.227841 -4.542
# 4    0.859585    0.510993 -3.145
#
# [5 rows x 36 columns]
#    Pitch_angle  Pitch_angle_std  Hub_temperature  Hub_temperature_std  \
# 0    -1.010000              0.0        20.969999                 0.23
# 1    89.980003              0.0        22.000000                 0.00
# 2    91.949997              0.0        26.000000                 0.00
# 3    -1.000000              0.0        22.000000                 0.02
# 4    -1.000000              0.0        13.000000                 0.00
#
#    Generator_converter_speed  Generator_converter_speed_std  Generator_speed  \
# 0                 1423.75000                      63.220001       1424.68990
# 1                    2.98000                       0.010000          0.00000
# 2                    2.85000                       0.010000          0.00000
# 3                 1447.54000                      69.230003       1448.60000
# 4                  992.89001                      57.000000        993.65997
#
#    Generator_speed_std  Generator_bearing_1_temperature  \
# 0            63.330002                        40.160000
# 1             0.000000                        39.860001
# 2             0.000000                        37.970001
# 3            69.360001                        42.439999
# 4            57.130001                        35.430000
#
#    Generator_bearing_1_temperature_std  ...  Grid_frequency  \
# 0                                 0.24  ...       50.049999
# 1                                 0.09  ...       50.000000
# 2                                 0.11  ...       50.020000
# 3                                 0.19  ...       49.980000
# 4                                 0.15  ...       50.009998
#
#    Grid_frequency_std  Rotor_speed  Rotor_speed_std  \
# 0                0.01        13.55             0.60
# 1                0.01         0.00             0.00
# 2                0.01         0.00             0.00
# 3                0.01        13.78             0.66
# 4                0.01         9.43             0.55
#
#    Rotor_bearing_temperature  Rotor_bearing_temperature_std  Nacelle_angle_c  \
# 0                  35.619999                           0.02       241.440000
# 1                  30.590000                           0.10        79.000000
# 2                  27.959999                           0.04        52.660000
# 3                  28.410000                           0.21       280.950010
# 4                  25.940001                           0.02        65.830002
#
#    AbsWindSin  AbsWindCos           Y
# 0   -0.799789   -0.600281  385.199000
# 1    0.570714    0.821149   -4.454000
# 2   -0.814217   -0.580561   -2.001000
# 3   -0.942233    0.334958  409.619011
# 4    0.976220    0.216780   90.850000
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Analyse exploratoire des données
#
# Nous commençons par explorer les données pour mieux comprendre les caractéristiques.

# %%
# Afficher les premières lignes donapp
donapp.head()
# Out:
#    Pitch_angle  Pitch_angle_std  Hub_temperature  Hub_temperature_std  \
# 0    92.410004              0.0             8.24                 0.28
# 1    92.410004              0.0             6.83                 0.49
# 2    92.410004              0.0             2.00                 0.00
# 3    92.410004              0.0             3.96                 0.44
# 4    92.410004              0.0             4.00                 0.00
#
#    Generator_converter_speed  Generator_converter_speed_std  Generator_speed  \
# 0                       3.92                           0.01             0.17
# 1                       3.93                           0.38             0.17
# 2                       4.26                           0.02             0.00
# 3                       4.09                           0.01             0.06
# 4                       4.46                           0.02             0.43
#
#    Generator_speed_std  Generator_bearing_1_temperature  \
# 0                 0.80                             7.70
# 1                 1.89                             7.70
# 2                 0.05                            -1.69
# 3                 0.34                            -0.23
# 4                 0.36                             0.75
#
#    Generator_bearing_1_temperature_std  ...  Grid_frequency  \
# 0                                 0.01  ...       49.980000
# 1                                 0.00  ...        0.000000
# 2                                 0.10  ...       50.000000
# 3                                 0.05  ...       49.959999
# 4                                 0.03  ...       49.990002
#
#    Grid_frequency_std  Rotor_speed  Rotor_speed_std  \
# 0                0.01          0.0              0.0
# 1               22.26          0.0              0.0
# 2                0.01          0.0              0.0
# 3                0.01          0.0              0.0
# 4                0.01          0.0              0.0
#
#    Rotor_bearing_temperature  Rotor_bearing_temperature_std  Nacelle_angle_c  \
# 0                       2.38                           0.06       302.899990
# 1                       2.32                           0.03       302.899990
# 2                      -2.10                           0.07       301.810000
# 3                      -2.08                           0.04        79.000000
# 4                      -2.02                           0.03        69.120003
#
#    AbsWindSin  AbsWindCos      Y
# 0   -0.853187    0.521605 -2.727
# 1   -0.836286    0.548293  0.100
# 2    0.995193    0.097930 -4.993
# 3    0.973698    0.227841 -4.542
# 4    0.859585    0.510993 -3.145
#
# [5 rows x 36 columns]

# %%
donapp.describe()
# Out:
#         Pitch_angle  Pitch_angle_std  Hub_temperature  Hub_temperature_std  \
# count  20423.000000     20423.000000     20423.000000         20423.000000
# mean      11.827245         0.966495        19.963960             0.088400
# std       26.054090         4.313085         6.827110             0.145344
# min      -30.410000         0.000000         0.320000             0.000000
# 25%       -1.010000         0.000000        15.000000             0.000000
# 50%       -1.000000         0.000000        20.000000             0.000000
# 75%        2.190000         0.000000        25.000000             0.130000
# max      156.820010        72.589996        37.040001             0.750000
#
#        Generator_converter_speed  Generator_converter_speed_std  \
# count               20423.000000                   20423.000000
# mean                 1092.020753                      62.578941
# std                   590.726621                      78.597941
# min                     0.000000                       0.000000
# 25%                   926.760010                      12.585000
# 50%                  1197.939900                      37.830002
# 75%                  1583.455000                      85.704998
# max                  1802.340000                     869.690000
#
#        Generator_speed  Generator_speed_std  Generator_bearing_1_temperature  \
# count     20423.000000         20423.000000                     20423.000000
# mean       1092.631547            62.788820                        39.810544
# std         591.885414            78.623959                         7.848546
# min          -0.040000             0.000000                        -2.490000
# 25%         927.039980            12.770000                        38.070000
# 50%        1198.760000            37.900002                        41.680000
# 75%        1585.015000            85.820000                        44.439999
# max        1803.740000           872.190000                        62.740002
#
#        Generator_bearing_1_temperature_std  ...  Grid_frequency  \
# count                         20423.000000  ...    20423.000000
# mean                              0.401748  ...       49.974002
# std                               0.305192  ...        1.067798
# min                               0.000000  ...        0.000000
# 25%                               0.180000  ...       49.990002
# 50%                               0.340000  ...       50.000000
# 75%                               0.530000  ...       50.009998
# max                               2.290000  ...       50.110001
#
#        Grid_frequency_std   Rotor_speed  Rotor_speed_std  \
# count        20423.000000  20423.000000     20423.000000
# mean             0.018661     10.387831         0.599220
# std              0.418653      5.638842         0.748875
# min              0.000000      0.000000         0.000000
# 25%              0.010000      8.800000         0.120000
# 50%              0.010000     11.390000         0.360000
# 75%              0.010000     15.080000         0.820000
# max             24.840000     17.180000         8.300000
#
#        Rotor_bearing_temperature  Rotor_bearing_temperature_std  \
# count               20423.000000                   20423.000000
# mean                   31.244530                       0.055423
# std                     7.181041                       0.041361
# min                    -5.200000                       0.000000
# 25%                    28.820000                       0.020000
# 50%                    32.770000                       0.050000
# 75%                    35.799999                       0.090000
# max                    43.880001                       0.420000
#
#        Nacelle_angle_c    AbsWindSin    AbsWindCos             Y
# count     20423.000000  20423.000000  20423.000000  20423.000000
# mean        178.807564     -0.100404     -0.104536    385.929542
# std          96.302313      0.711867      0.687229    469.385523
# min           0.240000     -1.000000     -1.000000    -17.357000
# 25%          81.199997     -0.796319     -0.783042     31.444500
# 50%         199.730000     -0.236499     -0.178287    210.651000
# 75%         252.420000      0.636819      0.556731    568.481022
# max         359.980010      1.000000      0.999999   2248.137000
#
# [8 rows x 36 columns]

# %%
dontest.describe()
# Out:
#        Pitch_angle  Pitch_angle_std  Hub_temperature  Hub_temperature_std  \
# count  5000.000000      5000.000000      5000.000000           5000.00000
# mean     12.253094         0.932626        19.952198              0.08898
# std      26.485466         4.169119         6.804603              0.14477
# min      -1.010000         0.000000         3.110000              0.00000
# 25%      -1.010000         0.000000        15.000000              0.00000
# 50%      -1.000000         0.000000        20.005000              0.00000
# 75%       3.832500         0.000000        25.000000              0.14000
# max      92.690002        53.529999        37.000000              0.52000
#
#        Generator_converter_speed  Generator_converter_speed_std  \
# count                5000.000000                    5000.000000
# mean                 1083.626507                      62.969090
# std                   593.532395                      80.506372
# min                     2.470000                       0.000000
# 25%                   926.747498                      12.642500
# 50%                  1181.075000                      37.195000
# 75%                  1578.990000                      85.285000
# max                  1801.150000                     866.530030
#
#        Generator_speed  Generator_speed_std  Generator_bearing_1_temperature  \
# count      5000.000000          5000.000000                      5000.000000
# mean       1084.180510            63.154790                        39.745494
# std         594.778258            80.564524                         8.035514
# min          -0.010000             0.000000                        -0.280000
# 25%         927.030030            12.780000                        38.020000
# 50%        1181.925000            37.280000                        41.664999
# 75%        1580.665000            85.454998                        44.450001
# max        1803.100000           867.280030                        59.270000
#
#        Generator_bearing_1_temperature_std  ...  Grid_frequency  \
# count                          5000.000000  ...     5000.000000
# mean                              0.392390  ...       49.989124
# std                               0.296019  ...        0.689836
# min                               0.000000  ...        1.240000
# 25%                               0.180000  ...       49.990002
# 50%                               0.340000  ...       50.000000
# 75%                               0.510000  ...       50.009998
# max                               3.030000  ...       50.139999
#
#        Grid_frequency_std  Rotor_speed  Rotor_speed_std  \
# count         5000.000000  5000.000000      5000.000000
# mean             0.016488    10.307510         0.602646
# std              0.340272     5.665904         0.767618
# min              0.000000     0.000000         0.000000
# 25%              0.010000     8.800000         0.120000
# 50%              0.010000    11.230000         0.360000
# 75%              0.010000    15.040000         0.820000
# max             23.780001    17.170000         8.260000
#
#        Rotor_bearing_temperature  Rotor_bearing_temperature_std  \
# count                5000.000000                    5000.000000
# mean                   31.182058                       0.055206
# std                     7.293819                       0.042187
# min                    -3.900000                       0.000000
# 25%                    29.040001                       0.020000
# 50%                    32.740002                       0.050000
# 75%                    35.622500                       0.090000
# max                    43.330002                       0.370000
#
#        Nacelle_angle_c   AbsWindSin   AbsWindCos            Y
# count      5000.000000  5000.000000  5000.000000  5000.000000
# mean        179.056960    -0.113169    -0.117763   385.279196
# std          95.541462     0.709539     0.685619   477.045071
# min           1.070000    -1.000000    -1.000000   -15.520000
# 25%          81.634998    -0.801410    -0.790449    28.939249
# 50%         199.730000    -0.257133    -0.212689   199.332000
# 75%         251.320010     0.614802     0.552555   567.985992
# max         359.980010     1.000000     1.000000  2250.997000
#
# [8 rows x 36 columns]

# %%
donapp.dtypes
# Out:
# Pitch_angle                            float64
# Pitch_angle_std                        float64
# Hub_temperature                        float64
# Hub_temperature_std                    float64
# Generator_converter_speed              float64
# Generator_converter_speed_std          float64
# Generator_speed                        float64
# Generator_speed_std                    float64
# Generator_bearing_1_temperature        float64
# Generator_bearing_1_temperature_std    float64
# Generator_bearing_2_temperature        float64
# Generator_bearing_2_temperature_std    float64
# Generator_stator_temperature           float64
# Generator_stator_temperature_std       float64
# Gearbox_bearing_1_temperature          float64
# Gearbox_bearing_1_temperature_std      float64
# Gearbox_bearing_2_temperature          float64
# Gearbox_bearing_2_temperature_std      float64
# Gearbox_inlet_temperature              float64
# Gearbox_inlet_temperature_std          float64
# Gearbox_oil_sump_temperature           float64
# Gearbox_oil_sump_temperature_std       float64
# Nacelle_angle                          float64
# Nacelle_temperature_std                float64
# Absolute_wind_direction                float64
# Outdoor_temperature_std                float64
# Grid_frequency                         float64
# Grid_frequency_std                     float64
# Rotor_speed                            float64
# Rotor_speed_std                        float64
# Rotor_bearing_temperature              float64
# Rotor_bearing_temperature_std          float64
# Nacelle_angle_c                        float64
# AbsWindSin                             float64
# AbsWindCos                             float64
# Y                                      float64
# dtype: object

# %%
import pandas as pd

# Vérifier les types de données
are_floats = all(donapp.dtypes == 'float64')

print("Toutes les colonnes sont de type float64: ", are_floats)
# Out:
# Toutes les colonnes sont de type float64:  True

# %%
# Afficher les premières lignes dontest
dontest.head()
# Out:
#    Pitch_angle  Pitch_angle_std  Hub_temperature  Hub_temperature_std  \
# 0    -1.010000              0.0        20.969999                 0.23
# 1    89.980003              0.0        22.000000                 0.00
# 2    91.949997              0.0        26.000000                 0.00
# 3    -1.000000              0.0        22.000000                 0.02
# 4    -1.000000              0.0        13.000000                 0.00
#
#    Generator_converter_speed  Generator_converter_speed_std  Generator_speed  \
# 0                 1423.75000                      63.220001       1424.68990
# 1                    2.98000                       0.010000          0.00000
# 2                    2.85000                       0.010000          0.00000
# 3                 1447.54000                      69.230003       1448.60000
# 4                  992.89001                      57.000000        993.65997
#
#    Generator_speed_std  Generator_bearing_1_temperature  \
# 0            63.330002                        40.160000
# 1             0.000000                        39.860001
# 2             0.000000                        37.970001
# 3            69.360001                        42.439999
# 4            57.130001                        35.430000
#
#    Generator_bearing_1_temperature_std  ...  Grid_frequency  \
# 0                                 0.24  ...       50.049999
# 1                                 0.09  ...       50.000000
# 2                                 0.11  ...       50.020000
# 3                                 0.19  ...       49.980000
# 4                                 0.15  ...       50.009998
#
#    Grid_frequency_std  Rotor_speed  Rotor_speed_std  \
# 0                0.01        13.55             0.60
# 1                0.01         0.00             0.00
# 2                0.01         0.00             0.00
# 3                0.01        13.78             0.66
# 4                0.01         9.43             0.55
#
#    Rotor_bearing_temperature  Rotor_bearing_temperature_std  Nacelle_angle_c  \
# 0                  35.619999                           0.02       241.440000
# 1                  30.590000                           0.10        79.000000
# 2                  27.959999                           0.04        52.660000
# 3                  28.410000                           0.21       280.950010
# 4                  25.940001                           0.02        65.830002
#
#    AbsWindSin  AbsWindCos           Y
# 0   -0.799789   -0.600281  385.199000
# 1    0.570714    0.821149   -4.454000
# 2   -0.814217   -0.580561   -2.001000
# 3   -0.942233    0.334958  409.619011
# 4    0.976220    0.216780   90.850000
#
# [5 rows x 36 columns]

# %%
dontest.dtypes
# Out:
# Pitch_angle                            float64
# Pitch_angle_std                        float64
# Hub_temperature                        float64
# Hub_temperature_std                    float64
# Generator_converter_speed              float64
# Generator_converter_speed_std          float64
# Generator_speed                        float64
# Generator_speed_std                    float64
# Generator_bearing_1_temperature        float64
# Generator_bearing_1_temperature_std    float64
# Generator_bearing_2_temperature        float64
# Generator_bearing_2_temperature_std    float64
# Generator_stator_temperature           float64
# Generator_stator_temperature_std       float64
# Gearbox_bearing_1_temperature          float64
# Gearbox_bearing_1_temperature_std      float64
# Gearbox_bearing_2_temperature          float64
# Gearbox_bearing_2_temperature_std      float64
# Gearbox_inlet_temperature              float64
# Gearbox_inlet_temperature_std          float64
# Gearbox_oil_sump_temperature           float64
# Gearbox_oil_sump_temperature_std       float64
# Nacelle_angle                          float64
# Nacelle_temperature_std                float64
# Absolute_wind_direction                float64
# Outdoor_temperature_std                float64
# Grid_frequency                         float64
# Grid_frequency_std                     float64
# Rotor_speed                            float64
# Rotor_speed_std                        float64
# Rotor_bearing_temperature              float64
# Rotor_bearing_temperature_std          float64
# Nacelle_angle_c                        float64
# AbsWindSin                             float64
# AbsWindCos                             float64
# Y                                      float64
# dtype: object

# %%
import pandas as pd

# Vérifier les types de données
are_floats = all(dontest.dtypes == 'float64')

print("Toutes les colonnes sont de type float64: ", are_floats)
# Out:
# Toutes les colonnes sont de type float64:  True

# %%
import pandas as pd

# Vérifier les noms de colonnes
columns_match = dontest.columns.equals(donapp.columns)

# Vérifier les types de données
dtypes_match = all(dontest.dtypes == donapp.dtypes)

print("Les noms de colonnes sont identiques: ", columns_match)
print("Les types de données sont identiques: ", dtypes_match)
# Out:
# Les noms de colonnes sont identiques:  True
# Les types de données sont identiques:  True

# %%
import pandas as pd

# Nombre de données manquantes dans dontest
missing_dontest = dontest.isnull().sum().sum()

# Nombre de données manquantes dans donapp
missing_donapp = donapp.isnull().sum().sum()

print("Données manquantes dans dontest:\n", missing_dontest)
print("Données manquantes dans donapp:\n", missing_donapp)
# Out:
# Données manquantes dans dontest:
#  0
# Données manquantes dans donapp:
#  0

# %% [markdown]
# ### Note
# >- dontest et donapp on bien les mêmes noms et types colonnes.
# >- toute leurs colonnes sont numériques, pas de données catégorielles.
# >- pas de données manquantes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualisation des distributions des variables pour explorer les données
donapp.describe()

# Visualiser la distribution de la variable cible 'Y' pour l'analyse initiale
plt.figure(figsize=(10, 6))
sns.histplot(donapp['Y'], kde=True)
plt.title("Distribution de la variable cible 'Y'")
plt.xlabel("Y")
plt.ylabel("Densité")
plt.show()

# Visualisation de la corrélation entre les variables pour identifier les plus pertinentes
plt.figure(figsize=(15, 12))
sns.heatmap(donapp.corr(), cmap="coolwarm", center=0, annot=False)
plt.title("Carte de corrélation entre les variables")
plt.show()

# %%
import pandas as pd
import numpy as np

# Calculer la matrice de corrélation
correlation_matrix = donapp.corr().abs()

# Fixer un seuil de corrélation pour identifier les corrélations fortes
threshold = 0.8

# Identifier les paires de caractéristiques fortement corrélées
high_corr_var = np.where(correlation_matrix > threshold)
high_corr_pairs = [(correlation_matrix.index[x], correlation_matrix.columns[y], correlation_matrix.iloc[x, y])
                   for x, y in zip(*high_corr_var) if x != y and x < y]

# Afficher les paires fortement corrélées
for var1, var2, corr_value in high_corr_pairs:
    print(f"Pair: {var1} - {var2} | Corrélation: {corr_value}")
# Out:
# Pair: Pitch_angle - Generator_converter_speed | Corrélation: 0.8254928993900449
# Pair: Pitch_angle - Generator_speed | Corrélation: 0.825596413588926
# Pair: Pitch_angle - Gearbox_bearing_1_temperature | Corrélation: 0.8212201137765457
# Pair: Pitch_angle - Gearbox_bearing_2_temperature | Corrélation: 0.8054808258802626
# Pair: Pitch_angle - Rotor_speed | Corrélation: 0.8249854735315252
# Pair: Generator_converter_speed - Generator_speed | Corrélation: 0.9999960434535051
# Pair: Generator_converter_speed - Gearbox_bearing_1_temperature | Corrélation: 0.8418527772859234
# Pair: Generator_converter_speed - Gearbox_bearing_2_temperature | Corrélation: 0.8571461789464582
# Pair: Generator_converter_speed - Rotor_speed | Corrélation: 0.999994709511637
# Pair: Generator_converter_speed_std - Generator_speed_std | Corrélation: 0.9998943539163042
# Pair: Generator_converter_speed_std - Rotor_speed_std | Corrélation: 0.9998457485065818
# Pair: Generator_speed - Gearbox_bearing_1_temperature | Corrélation: 0.8419855101392786
# Pair: Generator_speed - Gearbox_bearing_2_temperature | Corrélation: 0.8572735718606199
# Pair: Generator_speed - Rotor_speed | Corrélation: 0.9999972121697341
# Pair: Generator_speed_std - Rotor_speed_std | Corrélation: 0.999886874542297
# Pair: Generator_bearing_1_temperature - Generator_bearing_2_temperature | Corrélation: 0.9137504587413535
# Pair: Generator_bearing_1_temperature - Generator_stator_temperature | Corrélation: 0.8322160213351709
# Pair: Generator_bearing_1_temperature - Gearbox_inlet_temperature | Corrélation: 0.8436486587823698
# Pair: Generator_bearing_1_temperature - Gearbox_oil_sump_temperature | Corrélation: 0.8299782549569736
# Pair: Generator_bearing_1_temperature_std - Generator_bearing_2_temperature_std | Corrélation: 0.8251223746701657
# Pair: Generator_bearing_1_temperature_std - Generator_stator_temperature_std | Corrélation: 0.8032616429669043
# Pair: Generator_bearing_2_temperature - Generator_stator_temperature | Corrélation: 0.8582062821017183
# Pair: Generator_bearing_2_temperature - Gearbox_inlet_temperature | Corrélation: 0.8220310641335704
# Pair: Generator_bearing_2_temperature - Gearbox_oil_sump_temperature | Corrélation: 0.8212420615128379
# Pair: Generator_bearing_2_temperature - Rotor_bearing_temperature | Corrélation: 0.8290289213533358
# Pair: Generator_stator_temperature - Gearbox_bearing_1_temperature | Corrélation: 0.8832874841370815
# Pair: Generator_stator_temperature - Gearbox_bearing_2_temperature | Corrélation: 0.8772687908191283
# Pair: Generator_stator_temperature - Gearbox_oil_sump_temperature | Corrélation: 0.8972555630582479
# Pair: Generator_stator_temperature - Rotor_bearing_temperature | Corrélation: 0.8230889297076406
# Pair: Gearbox_bearing_1_temperature - Gearbox_bearing_2_temperature | Corrélation: 0.9891813310335248
# Pair: Gearbox_bearing_1_temperature - Gearbox_oil_sump_temperature | Corrélation: 0.8991185174812465
# Pair: Gearbox_bearing_1_temperature - Rotor_speed | Corrélation: 0.8419487227732471
# Pair: Gearbox_bearing_1_temperature - Rotor_bearing_temperature | Corrélation: 0.8204753468217849
# Pair: Gearbox_bearing_2_temperature - Gearbox_oil_sump_temperature | Corrélation: 0.9097308170718672
# Pair: Gearbox_bearing_2_temperature - Rotor_speed | Corrélation: 0.8572760979156221
# Pair: Gearbox_bearing_2_temperature - Rotor_bearing_temperature | Corrélation: 0.818036600343035
# Pair: Gearbox_inlet_temperature - Gearbox_oil_sump_temperature | Corrélation: 0.9268753368353169
# Pair: Gearbox_oil_sump_temperature - Rotor_bearing_temperature | Corrélation: 0.8615705074829418
# Pair: Nacelle_angle - Absolute_wind_direction | Corrélation: 0.8778836444596155
# Pair: Nacelle_angle - Nacelle_angle_c | Corrélation: 0.9999999166286048
# Pair: Absolute_wind_direction - Nacelle_angle_c | Corrélation: 0.8778825947582233
# Pair: Absolute_wind_direction - AbsWindSin | Corrélation: 0.8361954896639227

# %% [markdown]
# Si nous voulions mener ce mini projet plus loin, nous prendrions en compte ces fortes corrélation.
#
# Quelques possibilités pour gérer des corrélations fortes entre features :
# - Identifier les corrélations fortes : Utilisez la matrice de corrélation et recherchez les paires de variables ayant des corrélations supérieures à 0,8 ou inférieures à -0,8. (entre features, on exclue les paires avec Y)
# - Analyser l'importance des variables : Pour chaque paire fortement corrélée, identifiez laquelle des deux variables est la plus pertinente (ou éliminez la moins utile). Parfois, une analyse de l'importance des caractéristiques avec un modèle comme l’arbre de décision peut aider.
# - Éliminer les redondances : Si des variables corrélées ne sont pas toutes nécessaires, retirez celles qui apportent moins de valeur explicative ou qui pourraient introduire une colinéarité non souhaitée, en particulier pour notre modèles linéaires.
# - Utiliser des méthodes de réduction de dimension : Si de nombreuses variables sont corrélées, les techniques comme l’analyse en composantes principales (ACP) ou le regroupement de variables peuvent être utiles pour condenser l'information sans perdre en qualité de prédiction.
#
# Cependant, pour cet exercice, nous ne prêterons pas attention à ces fortes corrélations.

# %% [markdown]
# ### Note
# >- Distribution de Y : Montre la répartition des valeurs, ce qui aide à anticiper la complexité de la prédiction.
# >- Carte de corrélation : Permet d'identifier les variables potentiellement importantes pour prédire Y.

# %% [markdown]
# ## Modélisation et prédiction initiale
#
# Nous choisissons un modèle de régression linéaire de base pour effectuer une première estimation de la MSE sur les données de test.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Séparer les caractéristiques (X) et la cible (Y) pour le jeu de données d'apprentissage
X_train = donapp.drop(columns=['Y'])
y_train = donapp['Y']

# Pour les données de test
X_test = dontest.drop(columns=['Y'])
y_test = dontest['Y']

# Modèle de régression linéaire de base
model = LinearRegression()
model.fit(X_train, y_train)

# Prédictions et calcul de la MSE
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 19258.814114373432

# %% [markdown]
# ### Note
# >- La première estimation de la moyenne des erreurs de prévision au carré (MSE) pour le modèle de régression linéaire est de 19,258.81. Cette erreur nous donne une idée de la précision du modèle de base pour prédire la variable cible Y.

# %% [markdown]
# ## Classification en groupes et modélisation par groupe
#
# Nous effectuons une classification en 3 groupes avec K-means, puis ajustons un modèle de régression pour chaque groupe afin d'améliorer les prédictions.

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Standardisation des données
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Calculer l'inertie pour différents nombres de clusters
inertias = []
cluster_range = range(1, 10)  # On teste de 1 à 10 clusters

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

# Tracer le graphe de la méthode du coude
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertias, marker='o')
plt.axvline(x=3, color='red', linestyle='--')  # Ligne verticale sur 3 en rouge
plt.title("Méthode du coude pour déterminer le nombre optimal de clusters")
plt.xlabel("Nombre de clusters")
plt.ylabel("Inertie (somme des distances au carré)")
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Standardisation des données pour une meilleure performance de K-means
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Classification en 3 groupes avec K-means
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_train_scaled)

# Ajout des clusters aux données d'apprentissage
donapp['Cluster'] = clusters

# Visualisation de la distribution des clusters par rapport à la variable cible 'Y'
plt.figure(figsize=(10, 6))
sns.boxplot(x=donapp['Cluster'], y=donapp['Y'])
plt.title("Distribution de 'Y' par cluster")
plt.xlabel("Cluster")
plt.ylabel("Y")
plt.show()

# Vérifier la taille des clusters
donapp['Cluster'].value_counts()
# Out:
# Cluster
# 0    11000
# 1     5539
# 2     3884
# Name: count, dtype: int64

# %% [markdown]
# ### Note
# >Nous avons effectué une classification des données en 3 groupes avec K-means. Voici les tailles de chaque cluster :
#
# >- Cluster 1 : 11,000 observations
# >- Cluster 2 : 5,539 observations
# >- Cluster 0 : 3,884 observations
# >Ces groupes montrent une distribution différente pour la variable cible Y, ce qui peut indiquer qu'un modèle spécifique pour chaque cluster pourrait améliorer les prédictions. Nous allons maintenant entraîner un modèle de régression pour chaque cluster et effectuer les prédictions pour le jeu de données de test.

# %%
from sklearn.metrics import mean_squared_error

# Préparer un dictionnaire pour stocker les modèles et erreurs pour chaque cluster
models = {}
mse_per_cluster = {}

# Appliquer le même clustering au jeu de données de test
X_test_scaled = scaler.transform(X_test)
test_clusters = kmeans.predict(X_test_scaled)

# Pour chaque cluster, entraîner un modèle et faire les prédictions
for cluster_id in donapp['Cluster'].unique():
    # Extraire les données du cluster
    cluster_data = donapp[donapp['Cluster'] == cluster_id]
    X_cluster = cluster_data.drop(columns=['Y', 'Cluster'])
    y_cluster = cluster_data['Y']

    # Entraîner un modèle de régression pour ce cluster
    model = LinearRegression()
    model.fit(X_cluster, y_cluster)

    # Stocker le modèle
    models[cluster_id] = model

    # Filtrer les données de test pour le cluster actuel
    X_test_cluster = X_test[test_clusters == cluster_id]
    y_test_cluster = y_test[test_clusters == cluster_id]

    # Faire les prédictions et calculer l'erreur pour le cluster
    y_pred_cluster = model.predict(X_test_cluster)
    mse_cluster = mean_squared_error(y_test_cluster, y_pred_cluster)

    # Stocker la MSE pour le cluster
    mse_per_cluster[cluster_id] = mse_cluster

mse_per_cluster
# Out:
# {2: 203.8462403139863, 0: 13213.396332169692, 1: 9508.49344213593}

# %% [markdown]
# ### Note
# >- Ces résultats montrent que l’approche par clusters a permis de réduire l’erreur de prévision, surtout pour le Cluster 2 (203.84).
# >- Le modèle semble mieux adapté pour ce groupe, tandis que d’autres clusters présentent encore des erreurs élevées.
