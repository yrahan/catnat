# %% [markdown]
# # <p style="text-align: center;">Get Locations</p>

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

import glob
import os

import requests

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Set parameters

# %%
decree_filename_base = 'arrete_'
decrees_folder_name = './../../data/raw/decrees'
communes_folder_name = './../../data/raw/opendatasoft'
processed_data_folder_name = './../../data/processed'
decrees_filename = 'decrees.parquet'
decrees_locations_filename = 'decrees_locations.parquet'
communes_csv_filename = 'correspondance-code-insee-code-postal.csv'

# %%
(os.path.join(communes_folder_name, communes_csv_filename))
# Out:
# './../../data/raw/opendatasoft/correspondance-code-insee-code-postal.csv'

# %% [markdown]
# ## Import Decrees

# %%
df = pd.read_parquet(os.path.join(processed_data_folder_name, decrees_filename))

# %%
df.isna().sum()
# Out:
# insee               0
# nom_commune         0
# debut_evenement     0
# fin_evenement       0
# date_arrete         0
# date_parution_jo    0
# nom_peril           0
# code_peril          0
# franchise           0
# code_nor            0
# decision            0
# dtype: int64

# %%
df.head()
# Out:
#       insee           nom_commune debut_evenement fin_evenement date_arrete  \
# 43661  5063              LA GRAVE      2001-03-19    2001-03-25  2001-11-15
# 43662  5128  SAINT ANDRE D EMBRUN      2001-03-29    2001-03-29  2001-11-15
# 43663  6031              CANTARON      2000-11-23    2000-11-24  2001-11-15
# 43664  6031              CANTARON      2000-11-23    2000-11-24  2001-11-15
# 43665  6057            L'ESCARENE      2000-10-30    2000-10-31  2001-11-15
#
#       date_parution_jo                          nom_peril code_peril  \
# 43661       2001-12-01               Mouvement de Terrain        MVT
# 43662       2001-12-01               Mouvement de Terrain        MVT
# 43663       2001-12-01               Mouvement de Terrain        MVT
# 43664       2001-12-01  Inondations et/ou Coulées de Boue        ICB
# 43665       2001-12-01               Mouvement de Terrain        MVT
#
#       franchise      code_nor  decision
# 43661    Simple  INTE0100649A  Reconnue
# 43662    Simple  INTE0100649A  Reconnue
# 43663    Simple  INTE0100649A  Reconnue
# 43664    Simple  INTE0100649A  Reconnue
# 43665    Simple  INTE0100649A  Reconnue

# %%
df['decision'].value_counts()
# Out:
# decision
# Reconnue                                   130517
# Reconnue(sans impact sur la modulation)     65206
# Non reconnue                                39739
# Name: count, dtype: int64

# %% [markdown]
# ## Get Insee gps coodinates of communes.

# %%
communes_location = pd.read_csv(os.path.join(communes_folder_name, communes_csv_filename), sep=";")

# %%
communes_location.columns
# Out:
# Index(['Code INSEE', 'Code Postal', 'Commune', 'Département', 'Région',
#        'Statut', 'Altitude Moyenne', 'Superficie', 'Population',
#        'geo_point_2d', 'geo_shape', 'ID Geofla', 'Code Commune', 'Code Canton',
#        'Code Arrondissement', 'Code Département', 'Code Région'],
#       dtype='object')

# %%
communes_location.head()
# Out:
#   Code INSEE Code Postal        Commune        Département  \
# 0      59416       59190      MORBECQUE           ['NORD']
# 1      22102       22330      LANGOURLA  ["COTES-D'ARMOR"]
# 2      31225       31310  GOUTEVERNISSE  ['HAUTE-GARONNE']
# 3      23025       23220         BONNAT         ['CREUSE']
# 4      38522       38740    VALJOUFFREY          ['ISERE']
#
#                    Région                Statut  Altitude Moyenne  Superficie  \
# 0  ['NORD-PAS-DE-CALAIS']    ['Commune simple']              23.0      4455.0
# 1            ['BRETAGNE']    ['Commune simple']             170.0      2165.0
# 2       ['MIDI-PYRENEES']    ['Commune simple']             264.0       485.0
# 3            ['LIMOUSIN']  ['Chef-lieu canton']             355.0      4554.0
# 4         ['RHONE-ALPES']    ['Commune simple']            2009.0     12644.0
#
#    Population                            geo_point_2d  \
# 0         2.7    50.67689342861573, 2.536216144331492
# 1         0.6  48.284641107667674, -2.415501011324659
# 2         0.2   43.214026301449536, 1.173765920286677
# 3         1.3    46.32301933418213, 1.913450631364578
# 4         0.1     44.88153491127053, 6.07950399615059
#
#                                            geo_shape  ID Geofla  Code Commune  \
# 0  {"coordinates": [[[2.501239302134784, 50.63986...       1237           416
# 1  {"coordinates": [[[-2.416298136623701, 48.2530...      10183           102
# 2  {"coordinates": [[[1.165580460427912, 43.20037...      20555           225
# 3  {"coordinates": [[[1.952331841746855, 46.28624...       3586            25
# 4  {"coordinates": [[[6.056489736635054, 44.81581...       1082           522
#
#    Code Canton  Code Arrondissement Code Département  Code Région
# 0           30                    4               59           31
# 1            9                    1               22           53
# 2           27                    1               31           73
# 3            6                    2               23           74
# 4           36                    1               38           82

# %%
communes_location.isna().sum()
# Out:
# Code INSEE             0
# Code Postal            0
# Commune                0
# Département            0
# Région                 0
# Statut                 0
# Altitude Moyenne       0
# Superficie             0
# Population             0
# geo_point_2d           0
# geo_shape              0
# ID Geofla              0
# Code Commune           0
# Code Canton            0
# Code Arrondissement    0
# Code Département       0
# Code Région            0
# dtype: int64

# %%
communes_location['Code INSEE'].is_unique
# Out:
# True

# %%
# Merge DataFrames based on 'insee'

merged_df = pd.merge(df, communes_location[['Code INSEE', 'Code Postal', 'Commune', 'Département', 'Région',
       'Statut', 'Altitude Moyenne', 'Superficie', 'Population',
       'geo_point_2d', 'geo_shape', 'ID Geofla', 'Code Commune', 'Code Canton',
       'Code Arrondissement', 'Code Département', 'Code Région']],  left_on='insee', right_on='Code INSEE', how='left')

# %%
df.shape
# Out:
# (235462, 11)

# %%
merged_df.shape
# Out:
# (235462, 28)

# %%
merged_df.isna().sum()
# Out:
# insee                      0
# nom_commune                0
# debut_evenement            0
# fin_evenement              0
# date_arrete                0
# date_parution_jo           0
# nom_peril                  0
# code_peril                 0
# franchise                  0
# code_nor                   0
# decision                   0
# Code INSEE             13818
# Code Postal            13818
# Commune                13818
# Département            13818
# Région                 13818
# Statut                 13818
# Altitude Moyenne       13818
# Superficie             13818
# Population             13818
# geo_point_2d           13818
# geo_shape              13818
# ID Geofla              13818
# Code Commune           13818
# Code Canton            13818
# Code Arrondissement    13818
# Code Département       13818
# Code Région            13818
# dtype: int64

# %%
merged_df
# Out:
#         insee           nom_commune debut_evenement fin_evenement date_arrete  \
# 0        5063              LA GRAVE      2001-03-19    2001-03-25  2001-11-15
# 1        5128  SAINT ANDRE D EMBRUN      2001-03-29    2001-03-29  2001-11-15
# 2        6031              CANTARON      2000-11-23    2000-11-24  2001-11-15
# 3        6031              CANTARON      2000-11-23    2000-11-24  2001-11-15
# 4        6057            L'ESCARENE      2000-10-30    2000-10-31  2001-11-15
# ...       ...                   ...             ...           ...         ...
# 235457  90035                DORANS      2023-06-01    2023-09-30  2024-06-18
# 235458  90039                ESSERT      2023-01-01    2023-12-31  2024-06-18
# 235459  90045        FECHE L EGLISE      2023-07-01    2023-09-30  2024-06-18
# 235460  90068          MEROUX MOVAL      2023-01-01    2023-10-31  2024-06-18
# 235461  90095                SUARCE      2023-10-01    2023-12-31  2024-06-18
#
#        date_parution_jo                          nom_peril code_peril  \
# 0            2001-12-01               Mouvement de Terrain        MVT
# 1            2001-12-01               Mouvement de Terrain        MVT
# 2            2001-12-01               Mouvement de Terrain        MVT
# 3            2001-12-01  Inondations et/ou Coulées de Boue        ICB
# 4            2001-12-01               Mouvement de Terrain        MVT
# ...                 ...                                ...        ...
# 235457       2024-07-02                         Sécheresse        SEC
# 235458       2024-07-02                         Sécheresse        SEC
# 235459       2024-07-02                         Sécheresse        SEC
# 235460       2024-07-02                         Sécheresse        SEC
# 235461       2024-07-02                         Sécheresse        SEC
#
#        franchise      code_nor  ... Superficie Population  \
# 0         Simple  INTE0100649A  ...        NaN        NaN
# 1         Simple  INTE0100649A  ...        NaN        NaN
# 2         Simple  INTE0100649A  ...        NaN        NaN
# 3         Simple  INTE0100649A  ...        NaN        NaN
# 4         Simple  INTE0100649A  ...        NaN        NaN
# ...          ...           ...  ...        ...        ...
# 235457         -  IOME2415881A  ...      382.0        0.6
# 235458         -  IOME2415881A  ...      710.0        3.2
# 235459         -  IOME2415881A  ...      399.0        0.8
# 235460         -  IOME2415881A  ...      890.0        0.8
# 235461    Simple  IOME2415881A  ...     1187.0        0.4
#
#                                  geo_point_2d  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 235457   47.58474462701379, 6.837247587105974
# 235458   47.63670149621771, 6.811982362490323
# 235459  47.502176741594155, 6.955880312380269
# 235460  47.59254610319736, 6.9095726149755095
# 235461   47.56129565165385, 7.080055686636721
#
#                                                 geo_shape ID Geofla  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3                                                     NaN       NaN
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 235457  {"coordinates": [[[6.821011292623255, 47.57432...   20508.0
# 235458  {"coordinates": [[[6.807038927428798, 47.62266...   33825.0
# 235459  {"coordinates": [[[6.952446414801375, 47.48493...   25959.0
# 235460  {"coordinates": [[[6.921865974123075, 47.57813...   14506.0
# 235461  {"coordinates": [[[7.066592750582137, 47.54205...   15419.0
#
#        Code Commune Code Canton  Code Arrondissement  Code Département  \
# 0               NaN         NaN                  NaN               NaN
# 1               NaN         NaN                  NaN               NaN
# 2               NaN         NaN                  NaN               NaN
# 3               NaN         NaN                  NaN               NaN
# 4               NaN         NaN                  NaN               NaN
# ...             ...         ...                  ...               ...
# 235457         35.0        10.0                  1.0                90
# 235458         39.0         6.0                  1.0                90
# 235459         45.0        12.0                  1.0                90
# 235460         68.0        11.0                  1.0                90
# 235461         95.0        13.0                  1.0                90
#
#         Code Région
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 235457         43.0
# 235458         43.0
# 235459         43.0
# 235460         43.0
# 235461         43.0
#
# [235462 rows x 28 columns]

# %%
unique_values = merged_df[merged_df['Code INSEE'].isnull()]['nom_commune'].unique()

print(unique_values)
# Out:
# ['LA GRAVE' 'SAINT ANDRE D EMBRUN' 'CANTARON' ... 'VILLAR SAINT PANCRACE'
#  'NIBLES' 'CIVRIEUX']

# %%
unique_values.shape
# Out:
# (3061,)

# %%
merged_df_no_locations = merged_df[merged_df['Code INSEE'].isnull()]

# %%
merged_df_no_locations['debut_evenement'].max()
# Out:
# Timestamp('2024-05-24 00:00:00')

# %%
merged_df_no_locations['debut_evenement'].min()
# Out:
# Timestamp('1985-01-01 00:00:00')

# %%
merged_df_no_locations.head()
# Out:
#   insee           nom_commune debut_evenement fin_evenement date_arrete  \
# 0  5063              LA GRAVE      2001-03-19    2001-03-25  2001-11-15
# 1  5128  SAINT ANDRE D EMBRUN      2001-03-29    2001-03-29  2001-11-15
# 2  6031              CANTARON      2000-11-23    2000-11-24  2001-11-15
# 3  6031              CANTARON      2000-11-23    2000-11-24  2001-11-15
# 4  6057            L'ESCARENE      2000-10-30    2000-10-31  2001-11-15
#
#   date_parution_jo                          nom_peril code_peril franchise  \
# 0       2001-12-01               Mouvement de Terrain        MVT    Simple
# 1       2001-12-01               Mouvement de Terrain        MVT    Simple
# 2       2001-12-01               Mouvement de Terrain        MVT    Simple
# 3       2001-12-01  Inondations et/ou Coulées de Boue        ICB    Simple
# 4       2001-12-01               Mouvement de Terrain        MVT    Simple
#
#        code_nor  ... Superficie Population geo_point_2d geo_shape ID Geofla  \
# 0  INTE0100649A  ...        NaN        NaN          NaN       NaN       NaN
# 1  INTE0100649A  ...        NaN        NaN          NaN       NaN       NaN
# 2  INTE0100649A  ...        NaN        NaN          NaN       NaN       NaN
# 3  INTE0100649A  ...        NaN        NaN          NaN       NaN       NaN
# 4  INTE0100649A  ...        NaN        NaN          NaN       NaN       NaN
#
#   Code Commune Code Canton  Code Arrondissement  Code Département  Code Région
# 0          NaN         NaN                  NaN               NaN          NaN
# 1          NaN         NaN                  NaN               NaN          NaN
# 2          NaN         NaN                  NaN               NaN          NaN
# 3          NaN         NaN                  NaN               NaN          NaN
# 4          NaN         NaN                  NaN               NaN          NaN
#
# [5 rows x 28 columns]

# %%
merged_df_locations = merged_df[merged_df['Code INSEE'].notnull()]

# %%
merged_df_locations.head()
# Out:
#     insee             nom_commune debut_evenement fin_evenement date_arrete  \
# 12  12018         BALAGUIER D OLT      1990-01-01    1990-09-30  2001-11-15
# 13  12018         BALAGUIER D OLT      1992-03-01    1992-06-30  2001-11-15
# 14  14555  SAINT ANDRE D HEBERTOT      2000-11-06    2000-11-11  2001-11-15
# 15  14755             VILLERVILLE      2001-03-21    2001-03-23  2001-11-15
# 16  17118                CORIGNAC      1989-05-01    1989-12-31  2001-11-15
#
#    date_parution_jo             nom_peril code_peril franchise      code_nor  \
# 12       2001-12-01            Sécheresse        SEC    Simple  INTE0100649A
# 13       2001-12-01            Sécheresse        SEC    Simple  INTE0100649A
# 14       2001-12-01  Mouvement de Terrain        MVT    Simple  INTE0100649A
# 15       2001-12-01  Mouvement de Terrain        MVT    Simple  INTE0100649A
# 16       2001-12-01            Sécheresse        SEC    Simple  INTE0100649A
#
#     ... Superficie Population                           geo_point_2d  \
# 12  ...     1098.0        0.1   44.5189126443148, 1.9771926377212372
# 13  ...     1098.0        0.1   44.5189126443148, 1.9771926377212372
# 14  ...      988.0        0.5   49.30322090380799, 0.291910061831684
# 15  ...      342.0        0.8   49.39087631534191, 0.123148235678736
# 16  ...     1112.0        0.3  45.244860498269, -0.39280322020985503
#
#                                             geo_shape ID Geofla Code Commune  \
# 12  {"coordinates": [[[1.989175719192402, 44.49934...   15146.0         18.0
# 13  {"coordinates": [[[1.989175719192402, 44.49934...   15146.0         18.0
# 14  {"coordinates": [[[0.30899812835816304, 49.283...    5555.0        555.0
# 15  {"coordinates": [[[0.127262288895329, 49.37693...   14618.0        755.0
# 16  {"coordinates": [[[-0.41318672381903404, 45.22...   27409.0        118.0
#
#    Code Canton  Code Arrondissement  Code Département  Code Région
# 12         6.0                  3.0                12         73.0
# 13         6.0                  3.0                12         73.0
# 14         5.0                  3.0                14         25.0
# 15        35.0                  3.0                14         25.0
# 16        17.0                  1.0                17         54.0
#
# [5 rows x 28 columns]

# %%
merged_df_locations.isnull().sum()
# Out:
# insee                  0
# nom_commune            0
# debut_evenement        0
# fin_evenement          0
# date_arrete            0
# date_parution_jo       0
# nom_peril              0
# code_peril             0
# franchise              0
# code_nor               0
# decision               0
# Code INSEE             0
# Code Postal            0
# Commune                0
# Département            0
# Région                 0
# Statut                 0
# Altitude Moyenne       0
# Superficie             0
# Population             0
# geo_point_2d           0
# geo_shape              0
# ID Geofla              0
# Code Commune           0
# Code Canton            0
# Code Arrondissement    0
# Code Département       0
# Code Région            0
# dtype: int64

# %%
merged_df_locations.shape
# Out:
# (221644, 28)

# %%
merged_df_locations['debut_evenement'].max()
# Out:
# Timestamp('2024-05-24 00:00:00')

# %%
merged_df_locations['debut_evenement'].min()
# Out:
# Timestamp('1985-05-12 00:00:00')

# %%
len(merged_df_locations['Code INSEE'].unique())
# Out:
# 34396

# %%
# save to parquet
merged_df_locations.to_parquet(os.path.join(processed_data_folder_name, decrees_locations_filename))

# %% [markdown]
# ## Test reloading the dataframe from parquet

# %%
# test reloading the dataframe from parquet
import pandas as pd

df_reloaded = pd.read_parquet(os.path.join(processed_data_folder_name, decrees_locations_filename))

# %%
df_reloaded.head()
# Out:
#     insee             nom_commune debut_evenement fin_evenement date_arrete  \
# 12  12018         BALAGUIER D OLT      1990-01-01    1990-09-30  2001-11-15
# 13  12018         BALAGUIER D OLT      1992-03-01    1992-06-30  2001-11-15
# 14  14555  SAINT ANDRE D HEBERTOT      2000-11-06    2000-11-11  2001-11-15
# 15  14755             VILLERVILLE      2001-03-21    2001-03-23  2001-11-15
# 16  17118                CORIGNAC      1989-05-01    1989-12-31  2001-11-15
#
#    date_parution_jo             nom_peril code_peril franchise      code_nor  \
# 12       2001-12-01            Sécheresse        SEC    Simple  INTE0100649A
# 13       2001-12-01            Sécheresse        SEC    Simple  INTE0100649A
# 14       2001-12-01  Mouvement de Terrain        MVT    Simple  INTE0100649A
# 15       2001-12-01  Mouvement de Terrain        MVT    Simple  INTE0100649A
# 16       2001-12-01            Sécheresse        SEC    Simple  INTE0100649A
#
#     ... Superficie Population                           geo_point_2d  \
# 12  ...     1098.0        0.1   44.5189126443148, 1.9771926377212372
# 13  ...     1098.0        0.1   44.5189126443148, 1.9771926377212372
# 14  ...      988.0        0.5   49.30322090380799, 0.291910061831684
# 15  ...      342.0        0.8   49.39087631534191, 0.123148235678736
# 16  ...     1112.0        0.3  45.244860498269, -0.39280322020985503
#
#                                             geo_shape ID Geofla Code Commune  \
# 12  {"coordinates": [[[1.989175719192402, 44.49934...   15146.0         18.0
# 13  {"coordinates": [[[1.989175719192402, 44.49934...   15146.0         18.0
# 14  {"coordinates": [[[0.30899812835816304, 49.283...    5555.0        555.0
# 15  {"coordinates": [[[0.127262288895329, 49.37693...   14618.0        755.0
# 16  {"coordinates": [[[-0.41318672381903404, 45.22...   27409.0        118.0
#
#    Code Canton  Code Arrondissement  Code Département  Code Région
# 12         6.0                  3.0                12         73.0
# 13         6.0                  3.0                12         73.0
# 14         5.0                  3.0                14         25.0
# 15        35.0                  3.0                14         25.0
# 16        17.0                  1.0                17         54.0
#
# [5 rows x 28 columns]

# %%
df_reloaded.equals(merged_df_locations)
# Out:
# True

# %%
df_reloaded.describe()
# Out:
#                      debut_evenement                  fin_evenement  \
# count                         221644                         221644
# mean   2005-11-10 03:19:10.926711168  2006-02-16 10:27:57.890671488
# min              1985-05-12 00:00:00            1985-05-15 00:00:00
# 25%              1999-12-25 00:00:00            1999-12-29 00:00:00
# 50%              2003-07-01 00:00:00            2003-09-22 00:00:00
# 75%              2016-01-01 00:00:00            2016-03-31 00:00:00
# max              2024-05-24 00:00:00            2024-05-26 00:00:00
# std                              NaN                            NaN
#
#                          date_arrete               date_parution_jo  \
# count                         221644                         221644
# mean   2006-08-06 20:27:42.428037888  2006-08-18 15:24:08.744834048
# min              1987-06-24 00:00:00            1987-07-10 00:00:00
# 25%              1999-12-29 00:00:00            1999-12-30 00:00:00
# 50%              2003-12-12 00:00:00            2003-12-13 00:00:00
# 75%              2016-09-16 00:00:00            2016-10-20 00:00:00
# max              2024-06-18 00:00:00            2024-07-02 00:00:00
# std                              NaN                            NaN
#
#        Altitude Moyenne    Superficie     Population      ID Geofla  \
# count     221644.000000  2.216440e+05  221644.000000  221644.000000
# mean         210.044459  1.818752e+03       3.692151   17565.904870
# min            0.000000  2.000000e+00       0.000000       1.000000
# 25%           80.000000  7.270000e+02       0.300000    8120.000000
# 50%          143.000000  1.234000e+03       0.700000   17138.000000
# 75%          252.000000  2.152000e+03       2.100000   27022.250000
# max         2713.000000  1.871833e+06     440.200000   36613.000000
# std          232.417908  6.292843e+03      14.831298   10767.252219
#
#         Code Commune    Code Canton  Code Arrondissement    Code Région
# count  221644.000000  221644.000000        221644.000000  221644.000000
# mean      239.771760      22.711853             2.292469      52.248579
# min         1.000000       1.000000             0.000000       1.000000
# 25%       100.000000      10.000000             1.000000      26.000000
# 50%       207.000000      19.000000             2.000000      53.000000
# 75%       343.000000      30.000000             3.000000      73.000000
# max       909.000000      99.000000             9.000000      94.000000
# std       174.684157      18.132225             1.204191      25.544537

# %%
merged_df_locations.describe()
# Out:
#                      debut_evenement                  fin_evenement  \
# count                         221644                         221644
# mean   2005-11-10 03:19:10.926711168  2006-02-16 10:27:57.890671488
# min              1985-05-12 00:00:00            1985-05-15 00:00:00
# 25%              1999-12-25 00:00:00            1999-12-29 00:00:00
# 50%              2003-07-01 00:00:00            2003-09-22 00:00:00
# 75%              2016-01-01 00:00:00            2016-03-31 00:00:00
# max              2024-05-24 00:00:00            2024-05-26 00:00:00
# std                              NaN                            NaN
#
#                          date_arrete               date_parution_jo  \
# count                         221644                         221644
# mean   2006-08-06 20:27:42.428037888  2006-08-18 15:24:08.744834048
# min              1987-06-24 00:00:00            1987-07-10 00:00:00
# 25%              1999-12-29 00:00:00            1999-12-30 00:00:00
# 50%              2003-12-12 00:00:00            2003-12-13 00:00:00
# 75%              2016-09-16 00:00:00            2016-10-20 00:00:00
# max              2024-06-18 00:00:00            2024-07-02 00:00:00
# std                              NaN                            NaN
#
#        Altitude Moyenne    Superficie     Population      ID Geofla  \
# count     221644.000000  2.216440e+05  221644.000000  221644.000000
# mean         210.044459  1.818752e+03       3.692151   17565.904870
# min            0.000000  2.000000e+00       0.000000       1.000000
# 25%           80.000000  7.270000e+02       0.300000    8120.000000
# 50%          143.000000  1.234000e+03       0.700000   17138.000000
# 75%          252.000000  2.152000e+03       2.100000   27022.250000
# max         2713.000000  1.871833e+06     440.200000   36613.000000
# std          232.417908  6.292843e+03      14.831298   10767.252219
#
#         Code Commune    Code Canton  Code Arrondissement    Code Région
# count  221644.000000  221644.000000        221644.000000  221644.000000
# mean      239.771760      22.711853             2.292469      52.248579
# min         1.000000       1.000000             0.000000       1.000000
# 25%       100.000000      10.000000             1.000000      26.000000
# 50%       207.000000      19.000000             2.000000      53.000000
# 75%       343.000000      30.000000             3.000000      73.000000
# max       909.000000      99.000000             9.000000      94.000000
# std       174.684157      18.132225             1.204191      25.544537
