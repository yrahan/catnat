# %% [markdown]
# # <p style="text-align: center;">Concatenate Declarations of Natural Disaster Data</p>

# %%
decree_filename_base = 'arrete_'
decrees_folder_name = './../../data/raw/decrees'
processed_data_folder_name = './../../data/processed'
decrees_filename = 'decrees.parquet'

# %%
import pandas as pd
import glob
import os

path = decrees_folder_name  # Specify your folder path
all_files = glob.glob(os.path.join(path, "*.csv"))
all_files.sort()
#all_files = all_files[:2]
dfs = [pd.read_csv(filename, index_col=None, header=0, sep=';') for filename in all_files]
combined_df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
combined_df
# Out:
#        N° Insee      Nom de la commune Début d'Evénement Fin d'Evénement  \
# 0         01386  SAINT SORLIN EN BUGEY        06/11/1982      10/11/1982
# 1         01386  SAINT SORLIN EN BUGEY        06/11/1982      10/11/1982
# 2         06073                  ISOLA        06/11/1982      10/11/1982
# 3         06073                  ISOLA        06/11/1982      10/11/1982
# 4         06088                   NICE        06/11/1982      10/11/1982
# ...         ...                    ...               ...             ...
# 291799    90035                 DORANS        01/06/2023      30/09/2023
# 291800    90039                 ESSERT        01/01/2023      31/12/2023
# 291801    90045         FECHE L EGLISE        01/07/2023      30/09/2023
# 291802    90068           MEROUX MOVAL        01/01/2023      31/10/2023
# 291803    90095                 SUARCE        01/10/2023      31/12/2023
#
#          Arrêté du Parution au JO du                       Nom du péril  \
# 0       30/11/1982        02/12/1982                            Tempête
# 1       30/11/1982        02/12/1982  Inondations et/ou Coulées de Boue
# 2       30/11/1982        02/12/1982                            Tempête
# 3       30/11/1982        02/12/1982  Inondations et/ou Coulées de Boue
# 4       30/11/1982        02/12/1982                            Tempête
# ...            ...               ...                                ...
# 291799  18/06/2024        02/07/2024                         Sécheresse
# 291800  18/06/2024        02/07/2024                         Sécheresse
# 291801  18/06/2024        02/07/2024                         Sécheresse
# 291802  18/06/2024        02/07/2024                         Sécheresse
# 291803  18/06/2024        02/07/2024                         Sécheresse
#
#        Code péril Franchise      Code NOR      Décision
# 0             TMP    Simple           NaN      Reconnue
# 1             ICB    Simple           NaN      Reconnue
# 2             TMP    Simple           NaN      Reconnue
# 3             ICB    Simple           NaN      Reconnue
# 4             TMP    Simple           NaN      Reconnue
# ...           ...       ...           ...           ...
# 291799        SEC         -  IOME2415881A  Non reconnue
# 291800        SEC         -  IOME2415881A  Non reconnue
# 291801        SEC         -  IOME2415881A  Non reconnue
# 291802        SEC         -  IOME2415881A  Non reconnue
# 291803        SEC    Simple  IOME2415881A      Reconnue
#
# [291804 rows x 11 columns]

# %%
combined_df.dtypes
# Out:
# N° Insee             object
# Nom de la commune    object
# Début d'Evénement    object
# Fin d'Evénement      object
# Arrêté du            object
# Parution au JO du    object
# Nom du péril         object
# Code péril           object
# Franchise            object
# Code NOR             object
# Décision             object
# dtype: object

# %%
combined_df.columns
# Out:
# Index(['N° Insee', 'Nom de la commune', 'Début d'Evénement', 'Fin d'Evénement',
#        'Arrêté du', 'Parution au JO du', 'Nom du péril', 'Code péril',
#        'Franchise', 'Code NOR', 'Décision'],
#       dtype='object')

# %%
cols_to_convert = ["Début d'Evénement", "Fin d'Evénement","Arrêté du", "Parution au JO du"]
combined_df[cols_to_convert] = combined_df[cols_to_convert].apply(pd.to_datetime, errors='coerce',  dayfirst=True)

# %%
combined_df
# Out:
#        N° Insee      Nom de la commune Début d'Evénement Fin d'Evénement  \
# 0         01386  SAINT SORLIN EN BUGEY        1982-11-06      1982-11-10
# 1         01386  SAINT SORLIN EN BUGEY        1982-11-06      1982-11-10
# 2         06073                  ISOLA        1982-11-06      1982-11-10
# 3         06073                  ISOLA        1982-11-06      1982-11-10
# 4         06088                   NICE        1982-11-06      1982-11-10
# ...         ...                    ...               ...             ...
# 291799    90035                 DORANS        2023-06-01      2023-09-30
# 291800    90039                 ESSERT        2023-01-01      2023-12-31
# 291801    90045         FECHE L EGLISE        2023-07-01      2023-09-30
# 291802    90068           MEROUX MOVAL        2023-01-01      2023-10-31
# 291803    90095                 SUARCE        2023-10-01      2023-12-31
#
#         Arrêté du Parution au JO du                       Nom du péril  \
# 0      1982-11-30        1982-12-02                            Tempête
# 1      1982-11-30        1982-12-02  Inondations et/ou Coulées de Boue
# 2      1982-11-30        1982-12-02                            Tempête
# 3      1982-11-30        1982-12-02  Inondations et/ou Coulées de Boue
# 4      1982-11-30        1982-12-02                            Tempête
# ...           ...               ...                                ...
# 291799 2024-06-18        2024-07-02                         Sécheresse
# 291800 2024-06-18        2024-07-02                         Sécheresse
# 291801 2024-06-18        2024-07-02                         Sécheresse
# 291802 2024-06-18        2024-07-02                         Sécheresse
# 291803 2024-06-18        2024-07-02                         Sécheresse
#
#        Code péril Franchise      Code NOR      Décision
# 0             TMP    Simple           NaN      Reconnue
# 1             ICB    Simple           NaN      Reconnue
# 2             TMP    Simple           NaN      Reconnue
# 3             ICB    Simple           NaN      Reconnue
# 4             TMP    Simple           NaN      Reconnue
# ...           ...       ...           ...           ...
# 291799        SEC         -  IOME2415881A  Non reconnue
# 291800        SEC         -  IOME2415881A  Non reconnue
# 291801        SEC         -  IOME2415881A  Non reconnue
# 291802        SEC         -  IOME2415881A  Non reconnue
# 291803        SEC    Simple  IOME2415881A      Reconnue
#
# [291804 rows x 11 columns]

# %%
duplicateRows = combined_df[combined_df.duplicated()]

# %%
duplicateRows
# Out:
#        N° Insee    Nom de la commune Début d'Evénement Fin d'Evénement  \
# 22308      3001               ABREST        1982-11-06      1982-11-10
# 22311      3002              AGONGES        1982-11-06      1982-11-10
# 22314      3003     AINAY LE CHATEAU        1982-11-06      1982-11-10
# 22317      3004          ANDELAROCHE        1982-11-06      1982-11-10
# 22320      3005            ARCHIGNAT        1982-11-06      1982-11-10
# ...         ...                  ...               ...             ...
# 211520    85143              MERVENT        2009-01-01      2009-12-31
# 211525    85234  SAINT JEAN DE MONTS        2009-07-01      2009-09-30
# 247124    32088     CASTILLON DEBATS        2017-04-01      2017-12-31
# 256828    06151               UTELLE        2019-11-23      2019-11-24
# 287784    17216              LUSSANT        2023-06-16      2023-06-17
#
#         Arrêté du Parution au JO du          Nom du péril Code péril  \
# 22308  1982-11-18        1982-11-19               Tempête        TMP
# 22311  1982-11-18        1982-11-19               Tempête        TMP
# 22314  1982-11-18        1982-11-19               Tempête        TMP
# 22317  1982-11-18        1982-11-19               Tempête        TMP
# 22320  1982-11-18        1982-11-19               Tempête        TMP
# ...           ...               ...                   ...        ...
# 211520 2010-12-13        2011-01-13            Sécheresse        SEC
# 211525 2010-12-13        2011-01-13            Sécheresse        SEC
# 247124 2018-11-27        2018-12-07            Sécheresse        SEC
# 256828 2020-04-28        2020-06-12  Mouvement de Terrain        MVT
# 287784 2024-01-31        2024-02-09     Secousse Sismique        SEI
#
#        Franchise      Code NOR      Décision
# 22308     Simple           NaN      Reconnue
# 22311     Simple           NaN      Reconnue
# 22314     Simple           NaN      Reconnue
# 22317     Simple           NaN      Reconnue
# 22320     Simple           NaN      Reconnue
# ...          ...           ...           ...
# 211520         -  IOCE1032143A  Non reconnue
# 211525         -  IOCE1032143A  Non reconnue
# 247124    Simple  INTE1831447A      Reconnue
# 256828         -  INTE2010310A  Non reconnue
# 287784         -  IOME2334295A  Non reconnue
#
# [259 rows x 11 columns]

# %%
duplicateRows.shape
# Out:
# (259, 11)

# %%
combined_df.drop_duplicates(inplace=True)

# %%
combined_df.columns
# Out:
# Index(['N° Insee', 'Nom de la commune', 'Début d'Evénement', 'Fin d'Evénement',
#        'Arrêté du', 'Parution au JO du', 'Nom du péril', 'Code péril',
#        'Franchise', 'Code NOR', 'Décision'],
#       dtype='object')

# %%
column_mapping = {"N° Insee": "insee", "Nom de la commune": "nom_commune", 
"Début d'Evénement": "debut_evenement", "Fin d'Evénement": "fin_evenement", 
"Arrêté du": "date_arrete","Parution au JO du": "date_parution_jo",
"Nom du péril": "nom_peril", "Code péril": "code_peril",
"Franchise": "franchise", "Code NOR": "code_nor", "Décision": "decision"}
combined_df.rename(columns=column_mapping, inplace=True)

# %%
combined_df.columns
# Out:
# Index(['insee', 'nom_commune', 'debut_evenement', 'fin_evenement',
#        'date_arrete', 'date_parution_jo', 'nom_peril', 'code_peril',
#        'franchise', 'code_nor', 'decision'],
#       dtype='object')

# %%
combined_df.dtypes
# Out:
# insee                       object
# nom_commune                 object
# debut_evenement     datetime64[ns]
# fin_evenement       datetime64[ns]
# date_arrete         datetime64[ns]
# date_parution_jo    datetime64[ns]
# nom_peril                   object
# code_peril                  object
# franchise                   object
# code_nor                    object
# decision                    object
# dtype: object

# %%
combined_df['insee'].describe()
# Out:
# count     291545
# unique     55543
# top         6088
# freq          51
# Name: insee, dtype: int64

# %%
combined_df['insee'] = combined_df['insee'].astype(str)

# %%
combined_df.to_parquet(os.path.join(processed_data_folder_name, decrees_filename))

# %%
combined_df.head()
# Out:
#    insee            nom_commune debut_evenement fin_evenement date_arrete  \
# 0  01386  SAINT SORLIN EN BUGEY      1982-11-06    1982-11-10  1982-11-30
# 1  01386  SAINT SORLIN EN BUGEY      1982-11-06    1982-11-10  1982-11-30
# 2  06073                  ISOLA      1982-11-06    1982-11-10  1982-11-30
# 3  06073                  ISOLA      1982-11-06    1982-11-10  1982-11-30
# 4  06088                   NICE      1982-11-06    1982-11-10  1982-11-30
#
#   date_parution_jo                          nom_peril code_peril franchise  \
# 0       1982-12-02                            Tempête        TMP    Simple
# 1       1982-12-02  Inondations et/ou Coulées de Boue        ICB    Simple
# 2       1982-12-02                            Tempête        TMP    Simple
# 3       1982-12-02  Inondations et/ou Coulées de Boue        ICB    Simple
# 4       1982-12-02                            Tempête        TMP    Simple
#
#   code_nor  decision
# 0      NaN  Reconnue
# 1      NaN  Reconnue
# 2      NaN  Reconnue
# 3      NaN  Reconnue
# 4      NaN  Reconnue

# %%
combined_df.dtypes
# Out:
# insee                       object
# nom_commune                 object
# debut_evenement     datetime64[ns]
# fin_evenement       datetime64[ns]
# date_arrete         datetime64[ns]
# date_parution_jo    datetime64[ns]
# nom_peril                   object
# code_peril                  object
# franchise                   object
# code_nor                    object
# decision                    object
# dtype: object

# %%
import pandas as pd

# Using pyarrow engine
df_reloaded = pd.read_parquet(os.path.join(processed_data_folder_name, decrees_filename))

# %%
df_reloaded.head()
# Out:
#    insee            nom_commune debut_evenement fin_evenement date_arrete  \
# 0  01386  SAINT SORLIN EN BUGEY      1982-11-06    1982-11-10  1982-11-30
# 1  01386  SAINT SORLIN EN BUGEY      1982-11-06    1982-11-10  1982-11-30
# 2  06073                  ISOLA      1982-11-06    1982-11-10  1982-11-30
# 3  06073                  ISOLA      1982-11-06    1982-11-10  1982-11-30
# 4  06088                   NICE      1982-11-06    1982-11-10  1982-11-30
#
#   date_parution_jo                          nom_peril code_peril franchise  \
# 0       1982-12-02                            Tempête        TMP    Simple
# 1       1982-12-02  Inondations et/ou Coulées de Boue        ICB    Simple
# 2       1982-12-02                            Tempête        TMP    Simple
# 3       1982-12-02  Inondations et/ou Coulées de Boue        ICB    Simple
# 4       1982-12-02                            Tempête        TMP    Simple
#
#   code_nor  decision
# 0     None  Reconnue
# 1     None  Reconnue
# 2     None  Reconnue
# 3     None  Reconnue
# 4     None  Reconnue

# %%
df_reloaded.equals(combined_df)
# Out:
# True

# %%
df_reloaded.describe()
# Out:
#                      debut_evenement                  fin_evenement  \
# count                         291545                         291545
# mean   2001-06-12 23:33:40.146460928  2001-08-31 02:50:36.301085696
# min              1982-08-15 00:00:00            1982-08-15 00:00:00
# 25%              1991-08-31 00:00:00            1992-01-25 00:00:00
# 50%              1999-12-25 00:00:00            1999-12-29 00:00:00
# 75%              2011-08-02 00:00:00            2011-12-09 00:00:00
# max              2024-05-24 00:00:00            2024-05-26 00:00:00
#
#                          date_arrete               date_parution_jo
# count                         291545                         291545
# mean   2002-01-21 15:30:48.756109440  2002-01-31 22:56:52.915330816
# min              1982-09-21 00:00:00            1982-09-30 00:00:00
# 25%              1992-10-16 00:00:00            1992-10-17 00:00:00
# 50%              1999-12-29 00:00:00            1999-12-30 00:00:00
# 75%              2012-10-18 00:00:00            2012-10-21 00:00:00
# max              2024-06-18 00:00:00            2024-07-02 00:00:00

# %%
combined_df.describe()
# Out:
#                      debut_evenement                  fin_evenement  \
# count                         291545                         291545
# mean   2001-06-12 23:33:40.146460928  2001-08-31 02:50:36.301085696
# min              1982-08-15 00:00:00            1982-08-15 00:00:00
# 25%              1991-08-31 00:00:00            1992-01-25 00:00:00
# 50%              1999-12-25 00:00:00            1999-12-29 00:00:00
# 75%              2011-08-02 00:00:00            2011-12-09 00:00:00
# max              2024-05-24 00:00:00            2024-05-26 00:00:00
#
#                          date_arrete               date_parution_jo
# count                         291545                         291545
# mean   2002-01-21 15:30:48.756109440  2002-01-31 22:56:52.915330816
# min              1982-09-21 00:00:00            1982-09-30 00:00:00
# 25%              1992-10-16 00:00:00            1992-10-17 00:00:00
# 50%              1999-12-29 00:00:00            1999-12-30 00:00:00
# 75%              2012-10-18 00:00:00            2012-10-21 00:00:00
# max              2024-06-18 00:00:00            2024-07-02 00:00:00
